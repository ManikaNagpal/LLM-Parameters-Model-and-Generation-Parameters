# %% [markdown]
# This code does the following tasks:
# 1) Loads a model so you can run LLM inference.
#
# 2) Defines generation parameters so you can control:
#
# *   creativity
# *   randomness
# *   coherence
# *   length
# 3)  Generates text using those parameters
#
# It will allow you to experiment with different values and understand their effect.

# %% [markdown]
# # Importing Required Classes

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TextGenerationPipeline

# %% [markdown]
# # Load Model and Tokenizer

# %%
model_name = "meta-llama/Llama-2-7b-chat-hf"

# %%
from huggingface_hub import notebook_login
notebook_login()  # Login with your HF token

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto", torch_dtype="auto")
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %% [markdown]
# # Create a Pipeline

# %%
pipe = TextGenerationPipeline(model=model, tokenizer=tokenizer)
# Out:
# Device set to use cuda:0

# %% [markdown]
# # Declaring Generation Parameters

# %%
generation_params = {
    "temperature": 0.7,     # Controls randomness
    "top_p": 0.9,           # Nucleus sampling (probability mass)
    "top_k": 50,            # Consider top-k likely tokens
    "max_new_tokens": 100,  # Maximum tokens to generate
    "repetition_penalty": 1.0, # Similar to frequency/presence penalty
}

# %% [markdown]
# # Define a Prompt

# %%
prompt = "Explain the importance of data privacy in simple words."

# %% [markdown]
# # Generate Output

# %%
output = pipe(
    prompt,
    **generation_params
)

# %%
print(output[0]["generated_text"])
# Out:
# Explain the importance of data privacy in simple words.
# Data privacy is the right to control access to personal information, including the right to know what information is being collected, how it is being used, and who has access to it. It is important because it helps protect individuals from identity theft, discrimination, and other harmful actions that can result from the misuse of personal information.
# In other words, data privacy is about keeping personal information safe and secure, and making sure that only authorized people have access to it

# %% [markdown]
# # Effect of Temperature

# %%
generation_params = {
    "temperature": 0.2,     # Controls randomness
    "top_p": 0.9,           # Nucleus sampling (probability mass)
    "top_k": 50,            # Consider top-k likely tokens
    "max_new_tokens": 100,  # Maximum tokens to generate
    "repetition_penalty": 1.0, # Similar to frequency/presence penalty
}

# %%
output = pipe(
    prompt,
    **generation_params
)

# %%
print(output[0]["generated_text"])
# Out:
# Explain the importance of data privacy in simple words.
# Data privacy is the right to control access to personal information. It is important because it helps protect individuals from identity theft, stalking, and other forms of harassment. It also helps to ensure that personal information is not used without consent or shared without permission.
# In today's digital age, data privacy is more important than ever. With the rise of social media, online shopping, and other digital technologies, there is a vast amount of personal information being

# %% [markdown]
# #Effect of Top-p

# %%
generation_params = {
    "temperature": 0.7,     # Controls randomness
    "top_p": 0.5,           # Nucleus sampling (probability mass)
    "top_k": 50,            # Consider top-k likely tokens
    "max_new_tokens": 100,  # Maximum tokens to generate
    "repetition_penalty": 1.0, # Similar to frequency/presence penalty
}

# %%
output = pipe(
    prompt,
    **generation_params
)

# %%
print(output[0]["generated_text"])
# Out:
# Explain the importance of data privacy in simple words.
# Data privacy is the right to control access to one's personal information. It is important because it helps protect individuals from identity theft, stalking, and other forms of harassment. It also helps to ensure that personal information is not used without consent, and that individuals are not discriminated against based on their personal information.
#
# In simple words, data privacy is about keeping personal information safe and secure, and only sharing it with people who are allowed to see

# %% [markdown]
# # Effect of Top-k

# %%
generation_params = {
    "temperature": 0.7,     # Controls randomness
    "top_p": 0.9,           # Nucleus sampling (probability mass)
    "top_k": 20,            # Consider top-k likely tokens
    "max_new_tokens": 100,  # Maximum tokens to generate
    "repetition_penalty": 1.0, # Similar to frequency/presence penalty
}

# %%
output = pipe(
    prompt,
    **generation_params
)

# %%
print(output[0]["generated_text"])
# Out:
# Explain the importance of data privacy in simple words.
# Data privacy is the right to control access to personal information and to have that information protected from unauthorized use, disclosure, or access. In today's digital age, data privacy is more important than ever, as more and more of our personal information is being collected, stored, and shared online.
# Here are some reasons why data privacy is important:
# 1. Prevention of Identity Theft: Personal information such as name, address, date of birth,

# %% [markdown]
# #Effect of Number of Tokens

# %%
generation_params = {
    "temperature": 0.7,     # Controls randomness
    "top_p": 0.9,           # Nucleus sampling (probability mass)
    "top_k": 50,            # Consider top-k likely tokens
    "max_new_tokens": 50,  # Maximum tokens to generate
    "repetition_penalty": 1.0, # Similar to frequency/presence penalty
}

# %%
output = pipe(
    prompt,
    **generation_params
)

# %%
print(output[0]["generated_text"])
# Out:
# Explain the importance of data privacy in simple words.
# Data privacy is the right to control access to personal information. It's important because it helps protect you from identity theft, stalking, and other forms of harassment. It also helps ensure that companies and organizations use your

# %% [markdown]
# # Effect of Repitition Penalty

# %%
generation_params = {
    "temperature": 0.7,     # Controls randomness
    "top_p": 0.9,           # Nucleus sampling (probability mass)
    "top_k": 50,            # Consider top-k likely tokens
    "max_new_tokens": 100,  # Maximum tokens to generate
    "repetition_penalty": 0.7, # Similar to frequency/presence penalty
}

# %%
output = pipe(
    prompt,
    **generation_params
)

# %%
print(output[0]["generated_text"])
# Out:
# Explain the importance of data privacy in simple words.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection of personal data.
#
# Data privacy refers to the protection
